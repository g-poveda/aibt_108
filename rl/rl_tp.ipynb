# %% [markdown]
# # Reinforcement Learning graded exercice

# %% [markdown]
# ## Environment simulation
#
# We will start with a simple deterministic control environment that we will make stochastic in a second phase.

# %% [markdown]
# ### Simple line control environment

# %% [markdown]
# We will begin with a very simple control problem consisting in maintaining a moving object along a straight line.
# We can control its acceleration as shown in the following picture.
# The objective is to keep minimum the distance between the object and the center line as long as possible.
# To make the problem a bit interesting, we constrain the norm of the acceleration to be larger than a given value $a_{min}$: $\forall t > 0, \Vert a(t) \Vert_2 \geqslant a_{min}$.
#
# ![Line control environment](line_control_diagram.png)

# %% [markdown]
# #### Mathematical modeling of the Reinforcement Learning problem

# %% [markdown]
# We want to learn to control the object using Reinforcement Learning.
# The state of the system must contain the minimal information required to update the physics of the system from the action, i.e. the acceleration of the object.
# In this case, we need at least the position and the speed of the object, thus the state will be defined at any time $t$ by $s(t)=(x(t), y(t), v_x(t), v_y(t))$
# Moreover, for classical RL algorithms to apply, we need to discretize the time every $\Delta t$ time units.
# We can now approximate the physics of the object movement with the following equations, knowing the initial state $s(0)=(x(0), y(0), v_x(0), v_y(0))$:
# - $\forall t > 0, v_x(t+\Delta t) = v_x(t) + a_x(t) \cdot \Delta t$ ;
# - $\forall t > 0, x(t+\Delta t) = x(t) + v_x(t) \cdot \Delta t$ ;
# - $\forall t > 0, v_y(t+\Delta t) = v_y(t) + a_y(t) \cdot \Delta t$ ;
# - $\forall t > 0, y(t+\Delta t) = y(t) + v_y(t) \cdot \Delta t$ ;
#
# Since we want to keep minimum the distance between the center line and the object, we will model the reward signal at any time $t$ by $r(t) = e^{-\vert y(t) \vert}$.
# By doing so, an RL agent who will try to maximize the cumulated sum of (discounted) rewards will try to keep $y(t)$ as close as possible to $0$ at any time step.
# There are two possible ways to enforce the constraint $\Vert a(t) \Vert_2 \geqslant a_{min}$ in RL:
# - either by ensuring that the algorithm will only select such actions ;
# - or by associating a very large penalty (i.e. negative reward) to transitions labelled with such actions.

# %% [markdown]
# #### Implementation in a scikit-decide environment

# %% [markdown]
# [OpenAI Gym](https://gym.openai.com/) is a popular Python software library to model RL environments in a standard way which can be exploited by RL algorithm libraries like [RLlib](https://www.ray.io/rllib) or [Stable Baselines](https://github.com/DLR-RM/stable-baselines3).
#
# OpenAI Gym - or Gym in short - provides well-known environment implementations like CartPole, but we can also implement our own environment by following their standards, which will allow us to solve our environment using well-implemented and efficient RL algorithms from the aforementioned libraries. We will use the open-source Airbus library [scikit-decide](https://github.com/airbus/scikit-decide) which will allow us to use either RLLib or Stable Baselines as underlying solvers.
#
# All we have to do is to implement a domain class with the following methods:
# ```python
# class State:
#     # Define your state class here
#     pass
#
# class Action:
#     # Define your action class here
#     pass
#
#
# class D(RLDomain, UnrestrictedActions, FullyObservable, Renderable):
#     T_state = State  # Type of states
#     T_observation = T_state  # Type of observations
#     T_event = Action  # Type of events
#     T_value = float  # Type of transition values (rewards or costs)
#     T_info = None  # Type of additional information in environment outcome
#
# class MyDomain(D):
#     def __init__(self):
#         # Declare your variables here, including the environment's state.
#         # Declare also the action and observation (i.e. state) spaces: the action space is used by the algorithm
#         # to select actions while the observation space is used by Deep RL algorithms to properly initialize
#         # the observation (i.e. state) layer of the tensors.
#         pass
#
#     def _state_reset(self) -> D.T_state:
#         # Initialize and return the initial state of the environment
#         pass
#
#     def _state_step(self, action: D.T_event) -> TransitionOutcome[D.T_state, Value[D.T_value], D.T_predicate, D.T_info]:
#         # Perform one simulation step of the environment, i.e. compute the state resulting from applying the given action in the current state.
#         # Don't forget to update the environment's state so that the next call to the step method will reason about the updated state.
#         # Must return a tuple (state, reward, done, info) where done is true if the episode should stop now and info is a dictionary that can be left empty.
#         pass
#
#     def  _get_observation_space_(self) -> Space[D.T_observation]:
#         pass
#
#     def _get_action_space_(self) -> Space[D.T_event]:
#         pass
#
#     def _render_from(self, memory: D.T_state, **kwargs: Any) -> Any:
#         # If you want to render something at each simulation step (e.g. an image, some text, etc.)
#         pass
# ```

# %% [markdown]
# #### It's your turn!
# Please fill in the missing lines in the definition below of the Gym environment which implements "simple line control" problem.

# %%
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in /Users/poveda_g/miniconda3/envs/aibt_env_2025/lib/python3.12/site-packages (2.6.1)

# %%
from typing import *
from numpy.typing import ArrayLike

from skdecide import *
from skdecide.builders.domain import *
from skdecide.hub.space.gym import *
import numpy as np
import pygame
from pygame import gfxdraw
from math import sqrt, exp, fabs


HORIZON = 200
ACCELERATION_MIN = 0.5
PENALTY = -1.0


class D(RLDomain, UnrestrictedActions, FullyObservable, Renderable):
    T_state = ArrayLike  # Type of states
    T_observation = T_state  # Type of observations
    T_event = ArrayLike  # Type of events
    T_action = T_event
    T_value = float  # Type of transition values (rewards or costs)
    T_info = None  # Type of additional information in environment outcome


class SimpleLineControlDomain(D):
    """This class mimics an OpenAI Gym environment"""

    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 50}

    def __init__(self):
        """Initialize GymDomain.
        # Parameters
        gym_env: The Gym environment (gym.env) to wrap.
        """
        inf = np.finfo(np.float32).max
        self.action_space = BoxSpace(
            np.array([-10.0, -10.0]), np.array([10.0, 10.0]), dtype=np.float32
        )
        self.observation_space = BoxSpace(
            np.array([-inf, -inf, -inf, -inf]),
            np.array([inf, inf, inf, inf]),
            dtype=np.float32,
        )
        self._delta_t = 0.01
        self._init_pos_x = 0.0
        self._init_pos_y = 0.25
        self._init_speed_x = 1.0
        self._init_speed_y = 0.0
        self._pos_x = None
        self._pos_y = None
        self._speed_x = None
        self._speed_y = None
        self._path = []

        self.screen = None
        self.clock = None
        self.isopen = True

    def get_state(self):
        return np.array(
            [self._pos_x, self._pos_y, self._speed_x, self._speed_y], dtype=np.float32
        )

    def set_state(self, state):
        self._pos_x = state[0]
        self._pos_y = state[1]
        self._speed_x = state[2]
        self._speed_y = state[3]

    def _state_reset(self) -> D.T_state:
        self._pos_x = self._init_pos_x
        self._pos_y = self._init_pos_y
        self._speed_x = self._init_speed_x
        self._speed_y = self._init_speed_y
        self._path = [(self._pos_x, self._pos_y)]
        return np.array(
            [self._pos_x, self._pos_y, self._speed_x, self._speed_y], dtype=np.float32
        )

    def _state_step(
        self, action: D.T_event
    ) -> TransitionOutcome[D.T_state, Value[D.T_value], D.T_predicate, D.T_info]:
        if sqrt(action[0]*action[0] + action[1]*action[1]) < ACCELERATION_MIN:
            obs = np.array(
                [self._pos_x, self._pos_y, self._speed_x, self._speed_y], dtype=np.float32
            )
            return TransitionOutcome(obs, Value(reward=PENALTY), True, {})
        self._speed_x = self._speed_x + action[0] * self._delta_t
        self._speed_y = self._speed_y + action[1] * self._delta_t
        #if self._speed_x < 0.:
        #    obs = np.array(
        #        [self._pos_x, self._pos_y, self._speed_x, self._speed_y], dtype=np.float32
        #    )
        #    return TransitionOutcome(obs, Value(reward=PENALTY), True, {})
        self._pos_x = self._pos_x + self._delta_t * self._speed_x
        self._pos_y = self._pos_y + self._delta_t * self._speed_y
        obs = np.array(
            [self._pos_x, self._pos_y, self._speed_x, self._speed_y], dtype=np.float32
        )
        reward = exp(-10*fabs(self._pos_y))
        done = bool(fabs(self._pos_y) > 0.33)
        self._path.append((self._pos_x, self._pos_y))
        return TransitionOutcome(
            obs, Value(reward=reward if not done else PENALTY), done, {}
        )

    def _get_observation_space_(self) -> Space[D.T_observation]:
        return self.observation_space

    def _get_action_space_(self) -> Space[D.T_event]:
        return self.action_space

    def close(self):
        if self.screen is not None:
            pygame.display.quit()
            pygame.quit()
            self.isopen = False

    def _render_from(self, memory: D.T_state, **kwargs: Any) -> Any:
        screen_width = 500
        screen_height = 100

        if self.screen is None:
            pygame.init()
            pygame.display.init()
            self.screen = pygame.display.set_mode((screen_width, screen_height))
        if self.clock is None:
            self.clock = pygame.time.Clock()

        self.surf = pygame.Surface((screen_width, screen_height))
        self.surf.fill((255, 255, 255))
        self.track = gfxdraw.hline(
            self.surf, 0, screen_width, int(screen_height / 2), (0, 0, 255)
        )

        if len(self._path) > 1:
            for p in range(len(self._path) - 1):
                gfxdraw.line(
                    self.surf,
                    int(self._path[p][0] * 100),
                    int(screen_height / 2 + self._path[p][1] * 100),
                    int(self._path[p + 1][0] * 100),
                    int(screen_height / 2 + self._path[p + 1][1] * 100),
                    (255, 0, 0),
                )

        self.surf = pygame.transform.flip(self.surf, False, True)
        self.screen.blit(self.surf, (0, 0))
        return np.transpose(
            np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
        )

# %% [markdown]
# Now we test a trajectory of a random RL agent.

# %%
from typing import *

from skdecide import *
from skdecide.builders.domain import *
from skdecide.builders.solver import *


class D(RLDomain, UnrestrictedActions, FullyObservable, Renderable):
    pass


class RandomSolver(DeterministicPolicySolver):
    T_domain = D

    def __init__(self, domain_factory, action_space) -> None:
        super().__init__(domain_factory)
        self.action_space = action_space

    def _get_next_action(self, observation: D.T_observation) -> D.T_event:
        return self.action_space.sample()

    def _is_policy_defined_for(self, observation: D.T_observation) -> bool:
        return True

# %%
import matplotlib.pyplot as plt
import random
from IPython import display
# %matplotlib inline

domain_factory = lambda: SimpleLineControlDomain()
domain = domain_factory()

def rollout(domain, solver, max_steps):
    obs = domain.reset()

    for i in range(max_steps):
        plt.imshow(domain.render())
        display.display(plt.gcf())
        display.clear_output(wait=True)
        outcome = domain.step(
            solver.sample_action(obs)
        )
        obs = outcome.observation

rollout(domain=domain, solver=RandomSolver(domain_factory, domain.get_action_space()), max_steps=100)
domain.close()

# %% [markdown]
# We optimize the RL agent using RLLib.

# %%
RayRLlib?
# Out:
# Init signature:
# RayRLlib(
#     domain_factory: 'Callable[[], Domain]',
#     algo_class: 'type[Algorithm]',
#     train_iterations: 'int',
#     config: 'Optional[AlgorithmConfig]' = None,
#     policy_configs: 'Optional[dict[str, dict]]' = None,
#     policy_mapping_fn: "Optional[Callable[[str, Optional['EpisodeV2'], Optional['RolloutWorker']], str]]" = None,
#     action_embed_sizes: 'Optional[dict[str, int]]' = None,
#     config_kwargs: 'Optional[dict[str, Any]]' = None,
#     callback: 'Callable[[RayRLlib], bool]' = <function RayRLlib.<lambda> at 0x32dfc1e40>,
#     **kwargs,
# ) -> 'None'
# Docstring:
# This class wraps a Ray RLlib solver (ray[rllib]) as a scikit-decide solver.
#
# !!! warning
#     Using this class requires Ray RLlib to be installed.
# Init docstring:
# Initialize Ray RLlib.
#
# # Parameters
# domain_factory: A callable with no argument returning the domain to solve (can be a mere domain class).
#     The resulting domain will be auto-cast to the level expected by the solver.
# algo_class: The class of Ray RLlib trainer/agent to wrap.
# train_iterations: The number of iterations to call the trainer's train() method.
# config: The configuration dictionary for the trainer.
# policy_configs: The mapping from policy id (str) to additional config (dict) (leave default for single policy).
# policy_mapping_fn: The function mapping agent ids to policy ids (leave default for single policy).
# action_embed_sizes: The mapping from policy id (str) to action embedding size (only used with domains filtering allowed actions per state, default to 2)
# config_kwargs: keyword arguments for the `AlgorithmConfigKwargs` class used to update programmatically the algorithm config.
#     Will be used by hyerparameters tuners like optuna. Should probably not be used directly by the user,
#     who could rather directly specify the correct `config`.
# callback: function called at each solver iteration.
#     If returning true, the solve process stops and exit the current train iteration.
#     However, if train_iterations > 1, another train loop will be entered after that.
#     (One can code its callback in such a way that further training loop are stopped directly after that.)
# File:           ~/miniconda3/envs/aibt_env_2025/lib/python3.12/site-packages/skdecide/hub/solver/ray_rllib/ray_rllib.py
# Type:           type
# Subclasses:

# %%
# Import the RL algorithm (Trainer) we would like to use.
from ray.rllib.algorithms.ppo import PPO
from skdecide.hub.solver.ray_rllib import RayRLlib

domain_factory = lambda: SimpleLineControlDomain()
domain = domain_factory()
assert RayRLlib.check_domain(domain)
solver_factory = lambda: RayRLlib(domain_factory, PPO, train_iterations=10)
solver = solver_factory()
solver.solve()

    # Test solution
rollout(
        domain=domain,
        solver=solver,
        max_steps=HORIZON,
)

# domain.close()
# Out:
# 2025-06-26 15:56:48,401	INFO worker.py:1619 -- Calling ray.init() again after it has already been called.
# 2025-06-26 15:56:51,289	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# 2025-06-26 15:57:26,699 | skdecide.utils | DEBUG | Logger is in verbose mode: all debug messages will be there for you to enjoy （〜^∇^ )〜
# 2025-06-26 15:57:26,699 | skdecide.utils | DEBUG | Episode 1 started with following observation:
# 2025-06-26 15:57:26,699 | skdecide.utils | DEBUG | [0.   0.25 1.   0.  ]
# 2025-06-26 15:57:26,736 | skdecide.utils | DEBUG | Action: [-0.3848238 -3.9838262]
# 2025-06-26 15:57:26,736 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0
| skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.13087519,  0.21852018,  1.4001577 , -0.4633086 ], dtype=float32), value=Value(reward=4.528625092058025e-12, cost=-4.528625092058025e-12), termination=False, info={})
# 2025-06-26 15:57:26,763 | skdecide.utils | DEBUG | Action: [ 8.844112 -9.749556]
# 2025-06-26 15:57:26,765 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.14576118,  0.21291213,  1.4885988 , -0.5608041 ], dtype=float32), value=Value(reward=8.43570217215873e-12, cost=-8.43570217215873e-12), termination=False, info={})
# 2025-06-26 15:57:26,766 | skdecide.utils | DEBUG | Action: [-2.2587652 -5.543936 ]
# 2025-06-26 15:57:26,768 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.16042128,  0.2067497 ,  1.4660112 , -0.61624354], dtype=float32), value=Value(reward=1.53855138173168e-11, cost=-1.53855138173168e-11), termination=False, info={})
# 2025-06-26 15:57:26,772 | skdecide.utils | DEBUG | Action: [ 4.7261047 10.       ]
# 2025-06-26 15:57:26,772 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.175554  ,  0.20158726,  1.5132722 , -0.5162435 ], dtype=float32), value=Value(reward=2.661297917406829e-11, cost=-2.661297917406829e-11), termination=False, info={})
# 2025-06-26 15:57:26,774 | skdecide.utils | DEBUG | Action: [10.         0.9193306]
# 2025-06-26 15:57:26,774 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.19168673,  0.19651677,  1.6132722 , -0.5070502 ], dtype=float32), value=Value(reward=4.710784074824841e-11, cost=-4.710784074824841e-11), termination=False, info={})
# 2025-06-26 15:57:26,776 | skdecide.utils | DEBUG | Action: [10.         3.7086372]
# 2025-06-26 15:57:26,777 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.20881945,  0.19181712,  1.7132722 , -0.46996385], dtype=float32), value=Value(reward=8.004138909203369e-11, cost=-8.004138909203369e-11), termination=False, info={})
# 2025-06-26 15:57:26,780 | skdecide.utils | DEBUG | Action: [6.857565  3.4093494]
# 2025-06-26 15:57:26,780 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.22663793,  0.18745843,  1.7818478 , -0.43587035], dtype=float32), value=Value(reward=1.2872264371498223e-10, cost=-1.2872264371498223e-10), termination=False, info={})
# 2025-06-26 15:57:26,781 | skdecide.utils | DEBUG | Action: [10.       -1.179575]
# 2025-06-26 15:57:26,782 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.24545641,  0.18298176,  1.8818479 , -0.44766608], dtype=float32), value=Value(reward=2.1270992480349323e-10, cost=-2.1270992480349323e-10), termination=False, info={})
# 2025-06-26 15:57:26,783 | skdecide.utils | DEBUG | Action: [ 7.989746  -2.7956686]
# 2025-06-26 15:57:26,783 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.26507387,  0.17822553,  1.9617453 , -0.47562277], dtype=float32), value=Value(reward=3.567846965142123e-10, cost=-3.567846965142123e-10), termination=False, info={})
# 2025-06-26 15:57:26,784 | skdecide.utils | DEBUG | Action: [ 2.014288 10.      ]
# 2025-06-26 15:57:26,785 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.28489274,  0.1744693 ,  1.9818882 , -0.37562278], dtype=float32), value=Value(reward=5.247756126924588e-10, cost=-5.247756126924588e-10), termination=False, info={})
# 2025-06-26 15:57:26,786 | skdecide.utils | DEBUG | Action: [-6.5133295 -5.8181615]
# 2025-06-26 15:57:26,786 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.30406028,  0.17013125,  1.9167548 , -0.4338044 ], dtype=float32), value=Value(reward=7.831770087513466e-10, cost=-7.831770087513466e-10), termination=False, info={})
# 2025-06-26 15:57:26,787 | skdecide.utils | DEBUG | Action: [10.        1.038209]
# 2025-06-26 15:57:26,787 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0
| skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.5817399 ,  0.13921958,  2.7440891 , -0.39061785], dtype=float32), value=Value(reward=2.4669966826944152e-08, cost=-2.4669966826944152e-08), termination=False, info={})
# 2025-06-26 15:57:26,806 | skdecide.utils | DEBUG | Action: [0.4438572 7.8998013]
# 2025-06-26 15:57:26,806 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.6092252 ,  0.13610338,  2.7485275 , -0.31161982], dtype=float32), value=Value(reward=3.374467449498613e-08, cost=-3.374467449498613e-08), termination=False, info={})
# 2025-06-26 15:57:26,808 | skdecide.utils | DEBUG | Action: [0.8791399 6.6330795]
# 2025-06-26 15:57:26,808 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.6367984 ,  0.1336505 ,  2.757319  , -0.24528903], dtype=float32), value=Value(reward=4.3263318462304604e-08, cost=-4.3263318462304604e-08), termination=False, info={})
# 2025-06-26 15:57:26,809 | skdecide.utils | DEBUG | Action: [ 2.0350351 10.       ]
# 2025-06-26 15:57:26,809 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.6645751 ,  0.1321976 ,  2.7776694 , -0.14528903], dtype=float32), value=Value(reward=5.03978010674126e-08, cost=-5.03978010674126e-08), termination=False, info={})
# 2025-06-26 15:57:26,811 | skdecide.utils | DEBUG | Action: [ 7.131975  -2.5303183]
# 2025-06-26 15:57:26,811 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.693065  ,  0.13049167,  2.848989  , -0.17059222], dtype=float32), value=Value(reward=6.130686207652205e-08, cost=-6.130686207652205e-08), termination=False, info={})
# 2025-06-26 15:57:26,812 | skdecide.utils | DEBUG | Action: [8.117184  1.3339157]
# 2025-06-26 15:57:26,812 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.7223666 ,  0.12891915,  2.930161  , -0.15725306], dtype=float32), value=Value(reward=7.379108748088166e-08, cost=-7.379108748088166e-08), termination=False, info={})
# 2025-06-26 15:57:26,814 | skdecide.utils | DEBUG | Action: [-2.7557158 -4.863376 ]
# 2025-06-26 15:57:26,814 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.7513926 ,  0.12686028,  2.9026039 , -0.20588683], dtype=float32), value=Value(reward=8.98081402892208e-08, cost=-8.98081402892208e-08), termination=False, info={})
# 2025-06-26 15:57:26,815 | skdecide.utils | DEBUG | Action: [-3.3394737 10.       ]
# 2025-06-26 15:57:26,816 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.7800847 ,  0.12580141,  2.869209  , -0.10588682], dtype=float32), value=Value(reward=9.869069335396161e-08, cost=-9.869069335396161e-08), termination=False, info={})
# 2025-06-26 15:57:26,817 | skdecide.utils | DEBUG | Action: [ 4.3774605 -3.2434454]
# 2025-06-26 15:57:26,817 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.80921453,  0.1244182 ,  2.9129837 , -0.13832128], dtype=float32), value=Value(reward=1.150599610306282e-07, cost=-1.150599610306282e-07), termination=False, info={})
# 2025-06-26 15:57:26,818 | skdecide.utils | DEBUG | Action: [  1.2086582 -10.       ]
# 2025-06-26 15:57:26,818 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.8384653 ,  0.12203499,  2.9250703 , -0.23832127], dtype=float32), value=Value(reward=1.4663042341650196e-07, cost=-1.4663042341650196e-07), termination=False, info={})
# 2025-06-26 15:57:26,820 | skdecide.utils | DEBUG | Action: [-10.          2.3577175]
# 2025-06-26 15:57:26,820 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.86671597,  0.11988755,  2.8250701 , -0.2147441 ], dtype=float32), value=Value(reward=1.7554126251100978e-07, cost=-1.7554126251100978e-07), termination=False, info={})
# 2025-06-26 15:57:26,821 | skdecide.utils | DEBUG | Action: [10. 10.]
# 2025-06-26 15:57
| skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.4407663 , -0.04967772,  7.3858604 ,  0.19054455], dtype=float32), value=Value(reward=0.0005139549724867048, cost=-0.0005139549724867048), termination=False, info={})
# 2025-06-26 15:57:26,978 | skdecide.utils | DEBUG | Action: [-4.6354284 10.       ]
# 2025-06-26 15:57:26,979 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.5141616 , -0.04677228,  7.339506  ,  0.29054454], dtype=float32), value=Value(reward=0.000682924522971411, cost=-0.000682924522971411), termination=False, info={})
# 2025-06-26 15:57:26,980 | skdecide.utils | DEBUG | Action: [ 2.4674082 -5.18615  ]
# 2025-06-26 15:57:26,980 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.5878034 , -0.04438544,  7.36418   ,  0.23868304], dtype=float32), value=Value(reward=0.0008699394157952852, cost=-0.0008699394157952852), termination=False, info={})
# 2025-06-26 15:57:26,982 | skdecide.utils | DEBUG | Action: [-0.55680656  6.1559086 ]
# 2025-06-26 15:57:26,982 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.6613894 , -0.04138302,  7.358612  ,  0.30024213], dtype=float32), value=Value(reward=0.0011736916515151768, cost=-0.0011736916515151768), termination=False, info={})
# 2025-06-26 15:57:26,984 | skdecide.utils | DEBUG | Action: [1.0972233 3.1279888]
# 2025-06-26 15:57:26,984 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.735085  , -0.0380678 ,  7.369584  ,  0.33152202], dtype=float32), value=Value(reward=0.0016374923611896144, cost=-0.0016374923611896144), termination=False, info={})
# 2025-06-26 15:57:26,985 | skdecide.utils | DEBUG | Action: [10.         5.0486183]
# ...
# 2025-06-26 15:57:27,015 | skdecide.utils | DEBUG | Action: [ 7.905342  -4.8031654]
# 2025-06-26 15:57:27,015 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([7.1551676 , 0.05464845, 7.536314  , 0.41970116], dtype=float32), value=Value(reward=0.0003190118501897792, cost=-0.0003190118501897792), termination=False, info={})
# 2025-06-26 15:57:27,017 | skdecide.utils | DEBUG | Action: [ 2.7358332 -2.3125653]
# 2025-06-26 15:57:27,017 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([7.2308044 , 0.05861421, 7.5636725 , 0.3965755 ], dtype=float32), value=Value(reward=0.000215352533069067, cost=-0.000215352533069067), termination=False, info={})
# 2025-06-26 15:57:27,018 | skdecide.utils | DEBUG | Action: [10.       -5.038867]
# 2025-06-26 15:57:27,019 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([7.3074408 , 0.06207608, 7.6636724 , 0.34618685], dtype=float32), value=Value(reward=0.00015435019212819675, cost=-0.00015435019212819675), termination=False, info={})
# 2025-06-26 15:57:27,020 | skdecide.utils | DEBUG | Action: [9.198833  7.9668217]
# 2025-06-26 15:57:27,020 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([7.3849974 , 0.06633463, 7.7556605 , 0.42585504], dtype=float32), value=Value(reward=0.00010203344435219339, cost=-0.00010203344435219339), termination=False, info={})
# 2025-06-26 15:57:27,022 | skdecide.utils | DEBUG | Action: [ 3.014512 -8.32349 ]
# 2025-06-26 15:57:27,022 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([7.462856  , 0.06976083, 7.7858057 , 0.34262013], dtype=float32), value=Value(reward=7.271588172839704e-05, cost=-7.271588172839704e-05), termination=False, info={})
# 2025-06-26 15:57:27,024 | skdecide.utils | DEBUG | Action: [-10.  10.]
# 2025-06-26 15:57:27,024 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([7.539714  , 0.07418703, 7.685806  , 0.44262016], dtype=float32), value=Value(reward=4.6109204145585746e-05, cost=-4.6109204145585746e-05), termination=False, info={})
# 2025-06-26 15:57:27,026 | skdecide.utils | DEBUG | Action: [ 8.234032 -2.173667]
# 2025-06-26 15:57:27,026 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([7
| skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([10.210766  ,  0.12576632,  8.046166  ,  0.26654637], dtype=float32), value=Value(reward=2.777325301900062e-07, cost=-2.777325301900062e-07), termination=False, info={})
# 2025-06-26 15:57:27,097 | skdecide.utils | DEBUG | Action: [-7.072279 10.      ]
# 2025-06-26 15:57:27,098 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([10.290521 ,  0.1294318,  7.975444 ,  0.3665464], dtype=float32), value=Value(reward=1.9081104951578316e-07, cost=-1.9081104951578316e-07), termination=False, info={})
# 2025-06-26 15:57:27,099 | skdecide.utils | DEBUG | Action: [ -3.4658484 -10.       ]
# 2025-06-26 15:57:27,099 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([10.369928  ,  0.13209726,  7.9407854 ,  0.26654637], dtype=float32), value=Value(reward=1.4552998841115209e-07, cost=-1.4552998841115209e-07), termination=False, info={})
# 2025-06-26 15:57:27,101 | skdecide.utils | DEBUG | Action: [ 7.306814  -2.9968586]
# 2025-06-26 15:57:27,101 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([10.450067  ,  0.13446303,  8.013853  ,  0.2365778 ], dtype=float32), value=Value(reward=1.1592737630949269e-07, cost=-1.1592737630949269e-07), termination=False, info={})
# 2025-06-26 15:57:27,102 | skdecide.utils | DEBUG | Action: [  0.06109142 -10.        ]
# 2025-06-26 15:57:27,102 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([10.530211  ,  0.13582881,  8.014464  ,  0.13657779], dtype=float32), value=Value(reward=1.0113561772819702e-07, cost=-1.0113561772819702e-07), termination=False, info={})
# 2025-06-26 15:57:27,104 | skdecide.utils | DEBUG | Action: [1.4742012 5.5719566]
# 2025-06-26 15:57:27,104 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([10.610504  ,  0.13775179,  8.029206  ,  0.19229735], dtype=float32), value=Value(reward=8.359659114599853e-08, cost=-8.359659114599853e-08), termination=False, info={})
# 2025-06-26 15:57:27,105 | skdecide.utils | DEBUG | Action: [8.40517   5.2415323]
# 2025-06-26 15:57:27,106 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([10.691636  ,  0.14019892,  8.113258  ,  0.24471268], dtype=float32), value=Value(reward=6.61353827354951e-08, cost=-6.61353827354951e-08), termination=False, info={})

# %%
rollout(
        domain=domain,
        solver=solver,
        max_steps=HORIZON,
)
# Out:
# 2025-06-26 15:57:57,793 | skdecide.utils | DEBUG | Logger is in verbose mode: all debug messages will be there for you to enjoy （〜^∇^ )〜
# 2025-06-26 15:57:57,795 | skdecide.utils | DEBUG | Episode 1 started with following observation:
# 2025-06-26 15:57:57,795 | skdecide.utils | DEBUG | [0.   0.25 1.   0.  ]
# 2025-06-26 15:57:57,801 | skdecide.utils | DEBUG | Action: [  3.3666267 -10.       ]
# 2025-06-26 15:57:57,802 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.01033666,  0.249     ,  1.0336663 , -0.1       ], dtype=float32), value=Value(reward=1.5865280116121846e-13, cost=-1.5865280116121846e-13), termination=False, info={})
# 2025-06-26 15:57:57,806 | skdecide.utils | DEBUG | Action: [-10.         -2.8528557]
# 2025-06-26 15:57:57,807 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0.01967333,  0.24771471,  0.9336663 , -0.12852855], dtype=float32), value=Value(reward=1.6295898538148018e-13, cost=-1.6295898538148018e-13), termination=False, info={})
# 2025-06-26 15:57:57,811 | skdecide.utils | DEBUG | Action: [10.       -8.578091]
# 2025-06-26 15:57:57,812 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 0
| skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.2235782 , -0.05428294,  5.2126207 ,  0.22337624], dtype=float32), value=Value(reward=0.000228864163223434, cost=-0.000228864163223434), termination=False, info={})
# 2025-06-26 15:57:58,019 | skdecide.utils | DEBUG | Action: [ 8.727461  -7.8893957]
# 2025-06-26 15:57:58,020 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.2765772 , -0.05283812,  5.2998953 ,  0.1444823 ], dtype=float32), value=Value(reward=0.00026886657993158576, cost=-0.00026886657993158576), termination=False, info={})
# 2025-06-26 15:57:58,021 | skdecide.utils | DEBUG | Action: [5.7386637 6.630747 ]
# 2025-06-26 15:57:58,022 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.3301501 , -0.05073022,  5.357282  ,  0.21078975], dtype=float32), value=Value(reward=0.00033555125339368815, cost=-0.00033555125339368815), termination=False, info={})
# 2025-06-26 15:57:58,023 | skdecide.utils | DEBUG | Action: [10.        3.012948]
# 2025-06-26 15:57:58,023 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.384723  , -0.04832103,  5.457282  ,  0.24091925], dtype=float32), value=Value(reward=0.0004349312881545237, cost=-0.0004349312881545237), termination=False, info={})
# 2025-06-26 15:57:58,025 | skdecide.utils | DEBUG | Action: [  3.4433174 -10.       ]
# 2025-06-26 15:57:58,025 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.43964   , -0.04691184,  5.4917154 ,  0.14091924], dtype=float32), value=Value(reward=0.0005039096888251474, cost=-0.0005039096888251474), termination=False, info={})
# 2025-06-26 15:57:58,026 | skdecide.utils | DEBUG | Action: [ 2.3862371 -5.0301485]
# 2025-06-26 15:57:58,026 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.4947958 , -0.04600566,  5.515578  ,  0.09061775], dtype=float32), value=Value(reward=0.0005541029862743771, cost=-0.0005541029862743771), termination=False, info={})
# 2025-06-26 15:57:58,027 | skdecide.utils | DEBUG | Action: [ 9.950344  -6.7468996]
# 2025-06-26 15:57:58,028 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.5509467 , -0.04577417,  5.615081  ,  0.02314876], dtype=float32), value=Value(reward=0.0005773097594736227, cost=-0.0005773097594736227), termination=False, info={})
# 2025-06-26 15:57:58,029 | skdecide.utils | DEBUG | Action: [9.801914 9.709293]
# 2025-06-26 15:57:58,029 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.6080775 , -0.04457176,  5.7131    ,  0.12024169], dtype=float32), value=Value(reward=0.0006624376606464152, cost=-0.0006624376606464152), termination=False, info={})
# 2025-06-26 15:57:58,031 | skdecide.utils | DEBUG | Action: [-10.  10.]
# 2025-06-26 15:57:58,031 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.6642087 , -0.04236934,  5.6131    ,  0.2202417 ], dtype=float32), value=Value(reward=0.0008111958519764702, cost=-0.0008111958519764702), termination=False, info={})
# 2025-06-26 15:57:58,032 | skdecide.utils | DEBUG | Action: [  7.279375 -10.      ]
# 2025-06-26 15:57:58,032 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.7210677 , -0.04116692,  5.685894  ,  0.12024169], dtype=float32), value=Value(reward=0.0009267060237297284, cost=-0.0009267060237297284), termination=False, info={})
# 2025-06-26 15:57:58,033 | skdecide.utils | DEBUG | Action: [10. 10.]
# 2025-06-26 15:57:58,034 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.7789266 , -0.03896451,  5.785894  ,  0.2202417 ], dtype=float32), value=Value(reward=0.0011753398266537655, cost=-0.0011753398266537655), termination=False, info={})
# 2025-06-26 15:57:58,035 | skdecide.utils | DEBUG | Action: [-9.381472  -1.9482594]
# 2025-06-26 15:57:58,035 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.8358474 , -0.03695691,  5.692079  ,  0.2007591 ], dtype=float32), value=Value(reward=0.0014133590038021432, cost=-0.0014133590038021432), termination=False, info={})
# 2025-06-26 15:57:58,037 | skdecide.utils | DEBUG | Action: [ 0.64595604 10.        ]
# 2025-06-26 15:57:58,037 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.8928328 , -0.03394932,  5.698539  ,  0.3007591 ], dtype=float32), value=Value(reward=0.0019114506074538894, cost=-0.0019114506074538894), termination=False, info={})
# 2025-06-26 15:57:58,038 | skdecide.utils | DEBUG | Action: [3.933424  2.5795364]
# 2025-06-26 15:57:58,039 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 3.9502115 , -0.03068378,  5.737873  ,  0.32655448], dtype=float32), value=Value(reward=0.0026679108140849643, cost=-0.0026679108140849643), termination=False, info={})
# 2025-06-26 15:57:58,040 | skdecide.utils | DEBUG | Action: [6.900423 9.855438]
# 2025-06-26 15:57:58,040 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 4.0082803 , -0.02643269,  5.806877  ,  0.42510885], dtype=float32), value=Value(reward=0.004130336610591802, cost=-0.004130336610591802), termination=False, info={})
# 2025-06-26 15:57:58,041 | skdecide.utils | DEBUG | Action: [0.2988205 9.71513  ]
# 2025-06-26 15:57:58,041 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 4.066379  , -0.02121009,  5.8098655 ,  0.5222601 ], dtype=float32), value=Value(reward=0.006966643317791455, cost=-0.006966643317791455), termination=False, info={})
# 2025-06-26 15:57:58,043 | skdecide.utils | DEBUG | Action: [10. 10.]
# 2025-06-26 15:57:58,043 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 4.1254773 , -0.01498749,  5.9098654 ,  0.62226015], dtype=float32), value=Value(reward=0.013203201226143903, cost=-0.013203201226143903), termination=False, info={})
# 2025-06-26 15:57:58,044 | skdecide.utils | DEBUG | Action: [-5.2409935  5.7035265]
# 2025-06-26 15:57:58,044 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 4.184052  , -0.00819453,  5.8574557 ,  0.6792954 ], dtype=float32), value=Value(reward=0.025812192572173036, cost=-0.025812192572173036), termination=False, info={})
# 2025-06-26 15:57:58,046 | skdecide.utils | DEBUG | Action: [10.       -2.283698]
# 2025-06-26 15:57:58,046 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 4.2436266e+00, -1.6299500e-03,  5.9574556e+00,  6.5645844e-01],
#       dtype=float32), value=Value(reward=0.050614270233499695, cost=-0.050614270233499695), termination=False, info={})
# 2025-06-26 15:57:58,047 | skdecide.utils | DEBUG | Action: [ 3.6473675 10.       ]
# 2025-06-26 15:57:58,047 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.3035660e+00, 5.9346342e-03, 5.9939294e+00, 7.5645840e-01],
#       dtype=float32), value=Value(reward=0.033111108120063806, cost=-0.033111108120063806), termination=False, info={})
# 2025-06-26 15:57:58,049 | skdecide.utils | DEBUG | Action: [-0.43064976 -4.2823877 ]
# 2025-06-26 15:57:58,049 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.363462  , 0.01307098, 5.9896226 , 0.71363455], dtype=float32), value=Value(reward=0.016208171539812986, cost=-0.016208171539812986), termination=False, info={})
# 2025-06-26 15:57:58,050 | skdecide.utils | DEBUG | Action: [-10. -10.]
# 2025-06-26 15:57:58,050 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.4223585 , 0.01920732, 5.8896227 , 0.6136345 ], dtype=float32), value=Value(reward=0.008628274078550286, cost=-0.008628274078550286), termination=False, info={})
# 2025-06-26 15:57:58,051 | skdecide.utils | DEBUG | Action: [-8.437187    0.36296654]
# 2025-06-26 15:57:58,052 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.480411  , 0.02537997, 5.8052506 , 0.6172642 ], dtype=float32), value=Value(reward=0.004587573161007602, cost=-0.004587573161007602), termination=False, info={})
# 2025-06-26 15:57:58,053 | skdecide.utils | DEBUG | Action: [-9.107686  3.159257]
# 2025-06-26 15:57:58,053 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.537553  , 0.03186854, 5.714174  , 0.64885676], dtype=float32), value=Value(reward=0.002360046446320308, cost=-0.002360046446320308), termination=False, info={})
# 2025-06-26 15:57:58,054 | skdecide.utils | DEBUG | Action: [10.       -5.055272]
# 2025-06-26 15:57:58,055 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.5956945 , 0.03785158, 5.814174  , 0.5983041 ], dtype=float32), value=Value(reward=0.0013201247075018264, cost=-0.0013201247075018264), termination=False, info={})
# 2025-06-26 15:57:58,056 | skdecide.utils | DEBUG | Action: [-8.209066  -4.8310685]
# 2025-06-26 15:57:58,056 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.653015  , 0.04335151, 5.7320833 , 0.5499934 ], dtype=float32), value=Value(reward=0.0007508969490719801, cost=-0.0007508969490719801), termination=False, info={})
# 2025-06-26 15:57:58,058 | skdecide.utils | DEBUG | Action: [ 10. -10.]
# 2025-06-26 15:57:58,058 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.711336  , 0.04785144, 5.832083  , 0.44999337], dtype=float32), value=Value(reward=0.00048714912033082135, cost=-0.00048714912033082135), termination=False, info={})
# 2025-06-26 15:57:58,059 | skdecide.utils | DEBUG | Action: [10.         5.2529154]
# 2025-06-26 15:57:58,060 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.770657  , 0.05287667, 5.932083  , 0.5025225 ], dtype=float32), value=Value(reward=0.00029978001777159705, cost=-0.00029978001777159705), termination=False, info={})
# 2025-06-26 15:57:58,061 | skdecide.utils | DEBUG | Action: [  0.87093544 -10.        ]
# 2025-06-26 15:57:58,061 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.830065  , 0.05690189, 5.9407926 , 0.40252253], dtype=float32), value=Value(reward=0.00020073657925683645, cost=-0.00020073657925683645), termination=False, info={})
# 2025-06-26 15:57:58,063 | skdecide.utils | DEBUG | Action: [  0.71054554 -10.        ]
# 2025-06-26 15:57:58,063 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.8895435 , 0.05992712, 5.947898  , 0.30252254], dtype=float32), value=Value(reward=0.00014851207863831776, cost=-0.00014851207863831776), termination=False, info={})
# 2025-06-26 15:57:58,064 | skdecide.utils | DEBUG | Action: [10.       -1.088459]
# 2025-06-26 15:57:58,064 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([4.9500227 , 0.0628435 , 6.0478983 , 0.29163796], dtype=float32), value=Value(reward=0.00011280957733459887, cost=-0.00011280957733459887), termination=False, info={})
# 2025-06-26 15:57:58,066 | skdecide.utils | DEBUG | Action: [ 3.26612  -9.420054]
# 2025-06-26 15:57:58,066 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([5.0108285 , 0.06481788, 6.0805593 , 0.1974374 ], dtype=float32), value=Value(reward=9.30977234921732e-05, cost=-9.30977234921732e-05), termination=False, info={})
# 2025-06-26 15:57:58,067 | skdecide.utils | DEBUG | Action: [-0.7057705 10.       ]
# 2025-06-26 15:57:58,068 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([5.0715632 , 0.06779224, 6.0735016 , 0.2974374 ], dtype=float32), value=Value(reward=6.906519798465279e-05, cost=-6.906519798465279e-05), termination=False, info={})
# 2025-06-26 15:57:58,069 | skdecide.utils | DEBUG | Action: [  2.6441813 -10.       ]
# 2025-06-26 15:57:58,070 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([5.1325626 , 0.06976662, 6.0999436 , 0.1974374 ], dtype=float32), value=Value(reward=5.693770308785759e-05, cost=-5.693770308785759e-05), termination=False, info={})
# 2025-06-26 15:57:58,071 | skdecide.utils | DEBUG | Action: [10.         4.7546196]
# 2025-06-26 15:57:58,071 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([5.1945624 , 0.07221646, 6.1999435 , 0.2449836 ], dtype=float32), value=Value(reward=4.52967286907172e-05, cost=-4.52967286907172e-05), termination=False, info={})
# 2025-06-26 15:57:58,073 | skdecide.utils | DEBUG | Action: [10.        -4.9017773]
# 2025-06-26 15:57:58,073 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([5.2575617 , 0.07417612, 6.2999434 , 0.19596583], dtype=float32), value=Value(reward=3.783631961248423e-05, cost=-3.783631961248423e-05), termination=False, info={})
# 2025-06-26 15:57:58,074 | skdecide.utils | DEBUG | Action: [ 9.522831  -6.6293187]
# 2025-06-26 15:57:58,075 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([5.321513  , 0.07547284, 6.3951716 , 0.12967263], dtype=float32), value=Value(reward=3.3737145700770194e-05, cost=-3.3737145700770194e-05), termination=False, info={})
# 2025-06-26 15:57:58,076 | skdecide.utils | DEBUG | Action: [ 10. -10.]
# 2025-06-26 15:57:58,076 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([5.386465  , 0.07576957, 6.4951715 , 0.02967264], dtype=float32), value=Value(reward=3.326289931900552e-05, cost=-3.326289931900552e-05), termination=False, info={})
# 2025-06-26 15:57:58,078 | skdecide.utils | DEBUG | Action: [ 2.283041  -5.3533783]
# 2025-06-26 15:57:58,078 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.451645  ,  0.07553095,  6.518002  , -0.02386115], dtype=float32), value=Value(reward=3.418587701193431e-05, cost=-3.418587701193431e-05), termination=False, info={})
# 2025-06-26 15:57:58,079 | skdecide.utils | DEBUG | Action: [ 10. -10.]
# 2025-06-26 15:57:58,080 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.517825  ,  0.07429235,  6.618002  , -0.12386115], dtype=float32), value=Value(reward=3.928722396265249e-05, cost=-3.928722396265249e-05), termination=False, info={})
# 2025-06-26 15:57:58,081 | skdecide.utils | DEBUG | Action: [  0.64223385 -10.        ]
# 2025-06-26 15:57:58,081 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.5840693 ,  0.07205373,  6.6244245 , -0.22386114], dtype=float32), value=Value(reward=4.919197429238418e-05, cost=-4.919197429238418e-05), termination=False, info={})
# 2025-06-26 15:57:58,083 | skdecide.utils | DEBUG | Action: [ 5.9266424 -4.2169976]
# 2025-06-26 15:57:58,083 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.650906  ,  0.06939343,  6.683691  , -0.26603112], dtype=float32), value=Value(reward=6.475872733773979e-05, cost=-6.475872733773979e-05), termination=False, info={})
# 2025-06-26 15:57:58,084 | skdecide.utils | DEBUG | Action: [10.        5.517812]
# 2025-06-26 15:57:58,085 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.7187433 ,  0.06728489,  6.783691  , -0.21085301], dtype=float32), value=Value(reward=8.115593687449509e-05, cost=-8.115593687449509e-05), termination=False, info={})
# 2025-06-26 15:57:58,086 | skdecide.utils | DEBUG | Action: [10. 10.]
# 2025-06-26 15:57:58,086 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.78758   ,  0.06617636,  6.883691  , -0.110853  ], dtype=float32), value=Value(reward=9.20064880425595e-05, cost=-9.20064880425595e-05), termination=False, info={})
# 2025-06-26 15:57:58,088 | skdecide.utils | DEBUG | Action: [6.4080486  0.86402416]
# 2025-06-26 15:57:58,088 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.8570576 ,  0.06515423,  6.9477715 , -0.10221276], dtype=float32), value=Value(reward=0.00010285681009743937, cost=-0.00010285681009743937), termination=False, info={})
# 2025-06-26 15:57:58,089 | skdecide.utils | DEBUG | Action: [10.       -7.972279]
# 2025-06-26 15:57:58,090 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.9275355 ,  0.06333488,  7.0477715 , -0.18193555], dtype=float32), value=Value(reward=0.00012515636661458037, cost=-0.00012515636661458037), termination=False, info={})
# 2025-06-26 15:57:58,091 | skdecide.utils | DEBUG | Action: [ 1.4317598 -2.601368 ]
# 2025-06-26 15:57:58,091 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 5.9981565 ,  0.06125539,  7.062089  , -0.20794924], dtype=float32), value=Value(reward=0.00015439937165535796, cost=-0.00015439937165535796), termination=False, info={})
# 2025-06-26 15:57:58,092 | skdecide.utils | DEBUG | Action: [10.         -0.15298653]
# 2025-06-26 15:57:58,093 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 6.0697775,  0.0591606,  7.162089 , -0.2094791], dtype=float32), value=Value(reward=0.0001930757240312118, cost=-0.0001930757240312118), termination=False, info={})
# 2025-06-26 15:57:58,094 | skdecide.utils | DEBUG | Action: [ 4.3268223 10.       ]
# 2025-06-26 15:57:58,094 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 6.141831  ,  0.05806581,  7.205357  , -0.1094791 ], dtype=float32), value=Value(reward=0.00021671533512598046, cost=-0.00021671533512598046), termination=False, info={})
# 2025-06-26 15:57:58,096 | skdecide.utils | DEBUG | Action: [  5.3179245 -10.       ]
# 2025-06-26 15:57:58,096 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 6.214416  ,  0.05597102,  7.2585363 , -0.2094791 ], dtype=float32), value=Value(reward=0.0002691899281262326, cost=-0.0002691899281262326), termination=False, info={})
# 2025-06-26 15:57:58,097 | skdecide.utils | DEBUG | Action: [ 4.0281916 10.       ]
# 2025-06-26 15:57:58,098 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 6.2874045 ,  0.05487622,  7.2988186 , -0.1094791 ], dtype=float32), value=Value(reward=0.0003020010611242608, cost=-0.0003020010611242608), termination=False, info={})
# 2025-06-26 15:57:58,099 | skdecide.utils | DEBUG | Action: [10. 10.]
# 2025-06-26 15:57:58,100 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 6.3613925 ,  0.05478143,  7.3988185 , -0.0094791 ], dtype=float32), value=Value(reward=0.00030905444820195007, cost=-0.00030905444820195007), termination=False, info={})
# 2025-06-26 15:57:58,101 | skdecide.utils | DEBUG | Action: [-0.05376911  0.1357727 ]
# 2025-06-26 15:57:58,101 | skdecide.utils | DEBUG | Result: EnvironmentOutcome(observation=array([ 6.3613925 ,  0.05478143,  7.3988185 , -0.0094791 ], dtype=float32), value=Value(reward=-1.0, cost=1.0), termination=True, info={})
# 2025-06-26 15:57:58,102 | skdecide.utils | DEBUG | Episode 1 terminated after 165 steps.

# %% [markdown]
# ### Stochastic line control

# %% [markdown]
# Now we make the environment stochastic by assuming that the object actuators are noised in such a way that the lateral acceleration (along the y axis) follows a Gaussian distribution centered around the lateral acceleration command with a standard deviation depending on the magnitude of the longitudinal acceleration command.
# If we note $a^c_x(t)$ and $a^c_y(t)$ the acceleration command (RL actions), the actual accelerations that will act on the object are $a_x(t) = a^c_x(t)$ and $a_y(t) \sim \mathcal{N} \left( a^c_y(t), \sqrt{\vert a^c_x(t) \vert} \right)$.
# Please implement this stochastic domain in a Gym environment and implement an RLLib agent that learns to solve it.

# %%
### YOUR TURN ###

# %% [markdown]
# Please experiment with another noised acceleration model of your choice.

# %%
### YOUR TURN ###
